# %%
#DSA Assignment- Linked Lists

# %%
 #Q.1-Create a singly linked list in Python and perform basic traversal to display elements

# Create a Node class
class Node:
    def __init__(self, data):
        self.data = data    
        self.next = None    

# Create a LinkedList class
class LinkedList:
    def __init__(self):
        self.head = None   

    # Function to add new node at the end
    def insert(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            temp = self.head
            while temp.next:
                temp = temp.next
            temp.next = new_node

    # Function to traverse and display all elements
    def display(self):
        temp = self.head
        while temp:
            print(temp.data, end=" -> ")
            temp = temp.next
        print("None")  # end of list

ll = LinkedList()
ll.insert(10)
ll.insert(20)
ll.insert(30)

print("Linked List Elements:")
ll.display()
# Out:
# Linked List Elements:
# 10 -> 20 -> 30 -> None

# %%
# Q.2-Implement in sertion and deletion operations in singly and circular linked lists using Python classes.
###Singly linked list
# Create a Node class
class Node:
    def __init__(self, data):
        self.data = data    
        self.next = None    

# Create a LinkedList class
class LinkedList:
    def __init__(self):
        self.head = None   

    # Function to add new node at the end
    def insert(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            temp = self.head
            while temp.next:
                temp = temp.next
            temp.next = new_node

    # Delete a node by value
    def delete(self, value):
        temp = self.head

        # If list is empty
        if temp is None:
            print("List is empty")
            return

        # If head node is to be deleted
        if temp.data == value:
            self.head = temp.next
            temp = None
            return

        # Search for the node to delete
        prev = None
        while temp is not None and temp.data != value:
            prev = temp
            temp = temp.next

        # If value not found
        if temp is None:
            print("Value not found")
            return

        # Unlink the node
        prev.next = temp.next
        temp = None
    # Function to traverse and display all elements
    def display(self):
        temp = self.head
        while temp:
            print(temp.data, end=" -> ")
            temp = temp.next
        print("None")  # end of list

ll = LinkedList()
ll.insert(10)
ll.insert(20)
ll.insert(30)

print("Linked List Elements:")
ll.display()
 
sll.delete(20)
print("After deleting 20:")
sll.display()
# Out:
# Linked List Elements:
# 10 -> 20 -> 30 -> None
# Value not found
# After deleting 20:
# 10 -> 30 -> None

# %%
###Circular linked lists
# Node class
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# Circular Linked List class
class CircularLinkedList:
    def __init__(self):
        self.head = None

    # Insert at end
    def insert(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            new_node.next = self.head
        else:
            temp = self.head
            while temp.next != self.head:
                temp = temp.next
            temp.next = new_node
            new_node.next = self.head

    # Delete a node by value
    def delete(self, value):
        if self.head is None:
            print("List is empty")
            return

        current = self.head
        prev = None

        # Case 1: Node to delete is head
        if current.data == value:
            # If only one node
            if current.next == self.head:
                self.head = None
                return
            # Find the last node
            while current.next != self.head:
                current = current.next
            current.next = self.head.next
            self.head = self.head.next
            return

        # Case 2: Node to delete is not head
        prev = self.head
        current = self.head.next
        while current != self.head:
            if current.data == value:
                prev.next = current.next
                return
            prev = current
            current = current.next

        print("Value not found")

    # Display the circular list
    def display(self):
        if self.head is None:
            print("List is empty")
            return
        temp = self.head
        while True:
            print(temp.data, end=" -> ")
            temp = temp.next
            if temp == self.head:
                break
        print("(Back to Head)")

# --- Test the Circular Linked List ---
print("\nCircular Linked List:")
cll = CircularLinkedList()
cll.insert(10)
cll.insert(20)
cll.insert(30)
cll.display()

cll.delete(20)
print("After deleting 20:")
cll.display()
# Out:
# Circular Linked List:
# 10 -> 20 -> 30 -> (Back to Head)
# After deleting 20:
# 10 -> 30 -> (Back to Head)

# %%
# Write a Python program to create a doubly linked list and perform insertion, deletion, and bidirectional traversal.

# Node class
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None   # Pointer to previous node
        self.next = None   # Pointer to next node

# Doubly Linked List class
class DoublyLinkedList:
    def __init__(self):
        self.head = None

    # Insert at the end
    def insert(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            temp = self.head
            while temp.next:
                temp = temp.next
            temp.next = new_node
            new_node.prev = temp

    # Delete a node by value
    def delete(self, value):
        temp = self.head

        # If list is empty
        if temp is None:
            print("List is empty")
            return

        # If head is to be deleted
        if temp.data == value:
            self.head = temp.next
            if self.head:
                self.head.prev = None
            temp = None
            return

        # Otherwise, find the node to delete
        while temp and temp.data != value:
            temp = temp.next

        # Value not found
        if temp is None:
            print("Value not found")
            return

        # Update links
        if temp.next:
            temp.next.prev = temp.prev
        if temp.prev:
            temp.prev.next = temp.next
        temp = None

    # Forward traversal
    def display_forward(self):
        temp = self.head
        print("Forward Traversal:", end=" ")
        while temp:
            print(temp.data, end=" -> ")
            last = temp
            temp = temp.next
        print("None")

    # Backward traversal
    def display_backward(self):
        temp = self.head
        if temp is None:
            print("List is empty")
            return
        # Go to the last node
        while temp.next:
            temp = temp.next
        print("Backward Traversal:", end=" ")
        # Traverse backward using prev links
        while temp:
            print(temp.data, end=" -> ")
            temp = temp.prev
        print("None")

# --- Main Program ---
dll = DoublyLinkedList()
dll.insert(10)
dll.insert(20)
dll.insert(30)

dll.display_forward()
dll.display_backward()

dll.delete(20)
print("After deleting 20:")
dll.display_forward()
dll.display_backward()
# Out:
# Forward Traversal: 10 -> 20 -> 30 -> None
# Backward Traversal: 30 -> 20 -> 10 -> None
# After deleting 20:
# Forward Traversal: 10 -> 30 -> None
# Backward Traversal: 30 -> 10 -> None

# %%
##Thank you!!
