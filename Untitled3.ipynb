# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
iris = pd.read_csv("C:/Users/punam/OneDrive/Desktop/Book1.csv")

# Filter for the three species of interest
# Create the figure and axes
fig, ax = plt.subplots(1, 1, figsize=(10, 8))

# Create the explode list
explode = [0.1,0.1,0.1] * len(species_counts)

# Plot the pie chart
species_counts.plot.pie(
    explode=[0.1,0.1,,
    autopct='%1.1f%%',
    ax=ax
)

# Set the title
plt.title("Iris Species Distribution")
 # To remove the y-label
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 16
#      13 explode = [0.1,0.1,0.1] * len(species_counts)
#      15 # Plot the pie chart
# ---> 16 species_counts.plot.pie(
#      17     explode=explode,
#      18     autopct='%1.1f%%',
#      19     ax=ax
#      20 )
#      22 # Set the title
#      23 plt.title("Iris Species Distribution")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\plotting\_core.py:1658, in PlotAccessor.pie(self, **kwargs)
#    1652 if (
#    1653     isinstance(self._parent, ABCDataFrame)
#    1654     and kwargs.get("y", None) is None
#    1655     and not kwargs.get("subplots", False)
#    1656 ):
#    1657     raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1658 return self(kind="pie", **kwargs)
#
# ...
