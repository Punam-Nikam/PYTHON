# %%
def add(x,y):
    print("Addition is : ",x+y)
add(10,20)
# Out:
# Addition is :  30

# %%
list=[1,2,3,4,5]
list.reverse()
print(list)
# Out:
# [5, 4, 3, 2, 1]

# %%
list=[1,2,3,4,5]
for x in list:
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
list=[91,25,23,42,50]
list[1:5]
print(list)
# Out:
# [91, 25, 23, 42, 50]

# %%
list=[91,25,23,42,50]
list.remove(23)
print(list)
# Out:
# [91, 25, 42, 50]

# %%
list=[91,25,23,42,50]
list.remove(42)
print(list)
# Out:
# [91, 25, 23, 50]

# %%
list=[91,25,23,42,50]
list.clear()
print(list)
# Out:
# []

# %%
list=[91,25,23,42,50]
del(list[1])
print(list)
# Out:
# [91, 23, 42, 50]
